# %%
import tensorflow as tf
import numpy as np
import pickle
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
from tensorflow.examples.tutorials.mnist import input_data

# %%
mnist = input_data.read_data_sets(r'MNIST_data/')
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:262: extract_images (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-images-idx3-ubyte.gz
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:267: extract_labels (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use tf.data to implement this functionality.
# Extracting MNIST_data/train-labels-idx1-ubyte.gz
# Extracting MNIST_data/t10k-images-idx3-ubyte.gz
# Extracting MNIST_data/t10k-labels-idx1-ubyte.gz
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\contrib\learn\python\learn\datasets\mnist.py:290: DataSet.__init__ (from tensorflow.contrib.learn.python.learn.datasets.mnist) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use alternatives such as official/mnist/dataset.py from tensorflow/models.

# %%
img = mnist.train.images[50]
plt.imshow(img.reshape((28, 28)), cmap='Greys_r')

# %%
def get_inputs(real_size, noise_size):
    """
    真实图像tensor与噪声图像tensor
    """
    real_img = tf.placeholder(tf.float32, [None, real_size], name='real_img')
    noise_img = tf.placeholder(tf.float32, [None, noise_size], name='noise_img')
    
    return real_img, noise_img

# %%
def get_generator(noise_img, n_units, out_dim, reuse=False, alpha=0.01):
    """
    生成器
    
    noise_img: 生成器的输入
    n_units: 隐层单元个数
    out_dim: 生成器输出tensor的size，这里应该为32*32=784
    alpha: leaky ReLU系数
    """
    with tf.variable_scope("generator", reuse=reuse):
        # hidden layer
        hidden1 = tf.layers.dense(noise_img, n_units)
        # leaky ReLU
        hidden1 = tf.maximum(alpha * hidden1, hidden1)
        # dropout
        hidden1 = tf.layers.dropout(hidden1, rate=0.2)

        # logits & outputs
        logits = tf.layers.dense(hidden1, out_dim)
        outputs = tf.tanh(logits)
        
        return logits, outputs

# %%
def get_discriminator(img, n_units, reuse=False, alpha=0.01):
    """
    判别器
    
    n_units: 隐层结点数量
    alpha: Leaky ReLU系数
    """
    
    with tf.variable_scope("discriminator", reuse=reuse):
        # hidden layer
        hidden1 = tf.layers.dense(img, n_units)
        hidden1 = tf.maximum(alpha * hidden1, hidden1)
        
        # logits & outputs
        logits = tf.layers.dense(hidden1, 1)
        outputs = tf.sigmoid(logits)
        
        return logits, outputs

# %%
img_size = mnist.train.images[0].shape[0]
# 传入给generator的噪声size
noise_size = 100
# 生成器隐层参数
g_units = 128
# 判别器隐层参数
d_units = 128
# leaky ReLU的参数
alpha = 0.01

learning_rate = 0.001
# label smoothing
smooth = 0.1

# %%
tf.reset_default_graph()

real_img, noise_img = get_inputs(img_size, noise_size)

# generator
g_logits, g_outputs = get_generator(noise_img, g_units, img_size)

# discriminator
d_logits_real, d_outputs_real = get_discriminator(real_img, d_units)
d_logits_fake, d_outputs_fake = get_discriminator(g_outputs, d_units, reuse=True)
# Out:
# WARNING:tensorflow:From <ipython-input-12-61f994bd1269>:12: dense (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dense instead.
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From <ipython-input-12-61f994bd1269>:16: dropout (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.dropout instead.

# %%
# discriminator的loss
# 识别真实图片
d_loss_real = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_real, 
                                                                     labels=tf.ones_like(d_logits_real)) * (1 - smooth))
# 识别生成的图片
d_loss_fake = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake, 
                                                                     labels=tf.zeros_like(d_logits_fake)))
# 总体loss
d_loss = tf.add(d_loss_real, d_loss_fake)

# generator的loss
g_loss = tf.reduce_mean(tf.nn.sigmoid_cross_entropy_with_logits(logits=d_logits_fake,
                                                                labels=tf.ones_like(d_logits_fake)) * (1 - smooth))

# %%
train_vars = tf.trainable_variables()

# generator中的tensor
g_vars = [var for var in train_vars if var.name.startswith("generator")]
# discriminator中的tensor
d_vars = [var for var in train_vars if var.name.startswith("discriminator")]

# optimizer
d_train_opt = tf.train.AdamOptimizer(learning_rate).minimize(d_loss, var_list=d_vars)
g_train_opt = tf.train.AdamOptimizer(learning_rate).minimize(g_loss, var_list=g_vars)

# %%
# batch_size
batch_size = 64
# 训练迭代轮数
epochs = 300
# 抽取样本数
n_sample = 25

# 存储测试样例
samples = []
# 存储loss
losses = []
# 保存生成器变量
saver = tf.train.Saver(var_list = g_vars)
# 开始训练
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    for e in range(epochs):
        for batch_i in range(mnist.train.num_examples//batch_size):
            batch = mnist.train.next_batch(batch_size)
            
            batch_images = batch[0].reshape((batch_size, 784))
            # 对图像像素进行scale，这是因为tanh输出的结果介于(-1,1),real和fake图片共享discriminator的参数
            batch_images = batch_images*2 - 1
            
            # generator的输入噪声
            batch_noise = np.random.uniform(-1, 1, size=(batch_size, noise_size))
            
            # Run optimizers
            _ = sess.run(d_train_opt, feed_dict={real_img: batch_images, noise_img: batch_noise})
            _ = sess.run(g_train_opt, feed_dict={noise_img: batch_noise})
        
        # 每一轮结束计算loss
        train_loss_d = sess.run(d_loss, 
                                feed_dict = {real_img: batch_images, 
                                             noise_img: batch_noise})
        # real img loss
        train_loss_d_real = sess.run(d_loss_real, 
                                     feed_dict = {real_img: batch_images, 
                                                 noise_img: batch_noise})
        # fake img loss
        train_loss_d_fake = sess.run(d_loss_fake, 
                                    feed_dict = {real_img: batch_images, 
                                                 noise_img: batch_noise})
        # generator loss
        train_loss_g = sess.run(g_loss, 
                                feed_dict = {noise_img: batch_noise})
        
            
        print("Epoch {}/{}...".format(e+1, epochs),
              "Discriminator Loss: {:.4f}(Real: {:.4f} + Fake: {:.4f})...".format(train_loss_d, train_loss_d_real, train_loss_d_fake),
              "Generator Loss: {:.4f}".format(train_loss_g))    
        # 记录各类loss值
        losses.append((train_loss_d, train_loss_d_real, train_loss_d_fake, train_loss_g))
        
        # 抽取样本后期进行观察
        sample_noise = np.random.uniform(-1, 1, size=(n_sample, noise_size))
        gen_samples = sess.run(get_generator(noise_img, g_units, img_size, reuse=True),
                               feed_dict={noise_img: sample_noise})
        samples.append(gen_samples)
        
        # 存储checkpoints
        saver.save(sess, './checkpoints/generator.ckpt')

# 将sample的生成数据记录下来
with open('train_samples.pkl', 'wb') as f:
    pickle.dump(samples, f)
# Out:
# Epoch 1/300... Discriminator Loss: 0.0530(Real: 0.0194 + Fake: 0.0336)... Generator Loss: 3.9538
# Epoch 2/300... Discriminator Loss: 1.2704(Real: 0.2495 + Fake: 1.0209)... Generator Loss: 3.1839
# Epoch 3/300... Discriminator Loss: 0.4080(Real: 0.2173 + Fake: 0.1906)... Generator Loss: 3.1696
# Epoch 4/300... Discriminator Loss: 1.9576(Real: 1.2200 + Fake: 0.7376)... Generator Loss: 1.6601
# Epoch 5/300... Discriminator Loss: 0.8126(Real: 0.5336 + Fake: 0.2790)... Generator Loss: 3.0245
# Epoch 6/300... Discriminator Loss: 1.2812(Real: 0.6147 + Fake: 0.6665)... Generator Loss: 3.5016
# Epoch 7/300... Discriminator Loss: 1.4933(Real: 0.9867 + Fake: 0.5066)... Generator Loss: 1.6252
# Epoch 8/300... Discriminator Loss: 0.7375(Real: 0.4296 + Fake: 0.3079)... Generator Loss: 2.0854
# Epoch 9/300... Discriminator Loss: 1.1286(Real: 0.3900 + Fake: 0.7387)... Generator Loss: 2.1232
# Epoch 10/300... Discriminator Loss: 1.7276(Real: 0.7256 + Fake: 1.0020)... Generator Loss: 1.2590
# Epoch 11/300... Discriminator Loss: 1.2786(Real: 0.5948 + Fake: 0.6839)... Generator Loss: 1.2936
# Epoch 12/300... Discriminator Loss: 0.7005(Real: 0.4028 + Fake: 0.2977)... Generator Loss: 3.5009
# Epoch 13/300... Discriminator Loss: 0.7641(Real: 0.4746 + Fake: 0.2895)... Generator Loss: 2.3586
# Epoch 14/300... Discriminator Loss: 0.7052(Real: 0.5177 + Fake: 0.1874)... Generator Loss: 2.6893
# Epoch 15/300... Discriminator Loss: 1.4834(Real: 0.8133 + Fake: 0.6702)... Generator Loss: 1.1760
# Epoch 16/300... Discriminator Loss: 1.1203(Real: 0.7384 + Fake: 0.3820)... Generator Loss: 1.6967
# Epoch 17/300... Discriminator Loss: 0.9970(Real: 0.5329 + Fake: 0.4641)... Generator Loss: 1.7026
# Epoch 18/300... Discriminator Loss: 1.1774(Real: 0.4471 + Fake: 0.7303)... Generator Loss: 1.2170
# Epoch 19/300... Discriminator Loss: 0.7669(Real: 0.4327 + Fake: 0.3342)... Generator Loss: 1.4800
# Epoch 20/300... Discriminator Loss: 0.5279(Real: 0.2116 + Fake: 0.3163)... Generator Loss: 1.7570
# Epoch 21/300... Discriminator Loss: 1.4526(Real: 0.7158 + Fake: 0.7368)... Generator Loss: 1.2503
# Epoch 22/300... Discriminator Loss: 1.0748(Real: 0.5106 + Fake: 0.5643)... Generator Loss: 1.2264
# Epoch 23/300... Discriminator Loss: 0.8751(Real: 0.6295 + Fake: 0.2456)... Generator Loss: 2.2970
# Epoch 24/300... Discriminator Loss: 1.1649(Real: 0.5984 + Fake: 0.5665)... Generator Loss: 1.3298
# Epoch 25/300... Discriminator Loss: 1.1096(Real: 0.9075 + Fake: 0.2021)... Generator Loss: 2.2110
# Epoch 26/300... Discriminator Loss: 1.5970(Real: 1.0015 + Fake: 0.5955)... Generator Loss: 1.1493
# Epoch 27/300... Discriminator Loss: 1.0357(Real: 0.5452 + Fake: 0.4905)... Generator Loss: 1.4653
# Epoch 28/300... Discriminator Loss: 1.1356(Real: 0.4647 + Fake: 0.6709)... Generator Loss: 1.0220
# Epoch 29/300... Discriminator Loss: 0.7128(Real: 0.4663 + Fake: 0.2465)... Generator Loss: 2.1579
# Epoch 30/300... Discriminator Loss: 1.0636(Real: 0.8101 + Fake: 0.2534)... Generator Loss: 2.1262
# Epoch 31/300... Discriminator Loss: 0.9858(Real: 0.5593 + Fake: 0.4265)... Generator Loss: 1.5371
# Epoch 32/300... Discriminator Loss: 0.7980(Real: 0.3226 + Fake: 0.4755)... Generator Loss: 1.4951
# Epoch 33/300... Discriminator Loss: 1.0904(Real: 0.5659 + Fake: 0.5246)... Generator Loss: 1.5836
# Epoch 34/300... Discriminator Loss: 0.8819(Real: 0.6393 + Fake: 0.2426)... Generator Loss: 2.1596
# Epoch 35/300... Discriminator Loss: 0.6906(Real: 0.2789 + Fake: 0.4117)... Generator Loss: 1.6600
# Epoch 36/300... Discriminator Loss: 1.1339(Real: 0.5315 + Fake: 0.6024)... Generator Loss: 1.4145
# Epoch 37/300... Discriminator Loss: 1.0175(Real: 0.5372 + Fake: 0.4803)... Generator Loss: 1.6732
# Epoch 38/300... Discriminator Loss: 0.7474(Real: 0.2836 + Fake: 0.4638)... Generator Loss: 1.3311
# Epoch 39/300... Discriminator Loss: 0.8895(Real: 0.5550 + Fake: 0.3345)... Generator Loss: 1.7974
# Epoch 40/300... Discriminator Loss: 1.2822(Real: 0.5919 + Fake: 0.6904)... Generator Loss: 1.1801
# Epoch 41/300... Discriminator Loss: 1.1995(Real: 0.8437 + Fake: 0.3558)... Generator Loss: 1.8171
# Epoch 42/300... Discriminator Loss: 0.8192(Real: 0.3644 + Fake: 0.4548)... Generator Loss: 1.3290
# Epoch 43/300... Discriminator Loss: 1.1240(Real: 0.5057 + Fake: 0.6183)... Generator Loss: 1.2062
# Epoch 44/300... Discriminator Loss: 1.1613(Real: 0.5026 + Fake: 0.6588)... Generator Loss: 1.2923
# Epoch 45/300... Discriminator Loss: 1.3664(Real: 0.8829 + Fake: 0.4835)... Generator Loss: 1.3775
# Epoch 46/300... Discriminator Loss: 0.7507(Real: 0.4661 + Fake: 0.2846)... Generator Loss: 1.8702
# Epoch 47/300... Discriminator Loss: 0.9729(Real: 0.5239 + Fake: 0.4490)... Generator Loss: 1.5526
# Epoch 48/300... Discriminator Loss: 0.7669(Real: 0.4636 + Fake: 0.3032)... Generator Loss: 1.7283
# Epoch 49/300... Discriminator Loss: 0.8574(Real: 0.3840 + Fake: 0.4734)... Generator Loss: 1.3140
# Epoch 50/300... Discriminator Loss: 0.9831(Real: 0.4616 + Fake: 0.5215)... Generator Loss: 1.3328
# Epoch 51/300... Discriminator Loss: 0.9774(Real: 0.5859 + Fake: 0.3915)... Generator Loss: 1.7448
# Epoch 52/300... Discriminator Loss: 0.8666(Real: 0.5493 + Fake: 0.3173)... Generator Loss: 1.6667
# Epoch 53/300... Discriminator Loss: 1.0719(Real: 0.4664 + Fake: 0.6056)... Generator Loss: 1.0779
# Epoch 54/300... Discriminator Loss: 0.7920(Real: 0.3971 + Fake: 0.3949)... Generator Loss: 1.4644
# Epoch 55/300... Discriminator Loss: 0.9596(Real: 0.4561 + Fake: 0.5035)... Generator Loss: 1.4487
# Epoch 56/300... Discriminator Loss: 0.7463(Real: 0.3429 + Fake: 0.4034)... Generator Loss: 1.3576
# Epoch 57/300... Discriminator Loss: 0.9293(Real: 0.4522 + Fake: 0.4770)... Generator Loss: 1.3096
# Epoch 58/300... Discriminator Loss: 0.7533(Real: 0.3237 + Fake: 0.4296)... Generator Loss: 1.3968
# Epoch 59/300... Discriminator Loss: 0.9685(Real: 0.4670 + Fake: 0.5015)... Generator Loss: 1.3731
# Epoch 60/300... Discriminator Loss: 0.8470(Real: 0.4683 + Fake: 0.3787)... Generator Loss: 1.6024
# Epoch 61/300... Discriminator Loss: 0.8162(Real: 0.3329 + Fake: 0.4833)... Generator Loss: 1.3241
# Epoch 62/300... Discriminator Loss: 0.9620(Real: 0.4640 + Fake: 0.4980)... Generator Loss: 1.2725
# Epoch 63/300... Discriminator Loss: 0.8170(Real: 0.3753 + Fake: 0.4418)... Generator Loss: 1.3913
# Epoch 64/300... Discriminator Loss: 0.7962(Real: 0.4183 + Fake: 0.3779)... Generator Loss: 1.4853
# Epoch 65/300... Discriminator Loss: 0.9172(Real: 0.4853 + Fake: 0.4319)... Generator Loss: 1.6004
# Epoch 66/300... Discriminator Loss: 0.7571(Real: 0.4406 + Fake: 0.3165)... Generator Loss: 1.7306
# Epoch 67/300... Discriminator Loss: 0.9568(Real: 0.5339 + Fake: 0.4230)... Generator Loss: 1.3160
# Epoch 68/300... Discriminator Loss: 0.9951(Real: 0.4581 + Fake: 0.5370)... Generator Loss: 1.1968
# Epoch 69/300... Discriminator Loss: 1.0745(Real: 0.5092 + Fake: 0.5653)... Generator Loss: 1.1964
# Epoch 70/300... Discriminator Loss: 0.9626(Real: 0.3534 + Fake: 0.6092)... Generator Loss: 1.0266
# Epoch 71/300... Discriminator Loss: 1.1318(Real: 0.6120 + Fake: 0.5198)... Generator Loss: 1.4127
# Epoch 72/300... Discriminator Loss: 1.0769(Real: 0.5859 + Fake: 0.4910)... Generator Loss: 1.4192
# Epoch 73/300... Discriminator Loss: 0.8545(Real: 0.4075 + Fake: 0.4470)... Generator Loss: 1.4455
# Epoch 74/300... Discriminator Loss: 1.0066(Real: 0.4887 + Fake: 0.5178)... Generator Loss: 1.3584
# Epoch 75/300... Discriminator Loss: 0.9003(Real: 0.5843 + Fake: 0.3161)... Generator Loss: 1.7521
# Epoch 76/300... Discriminator Loss: 1.0138(Real: 0.4310 + Fake: 0.5828)... Generator Loss: 1.1776
# Epoch 77/300... Discriminator Loss: 1.0241(Real: 0.5165 + Fake: 0.5076)... Generator Loss: 1.4364
# Epoch 78/300... Discriminator Loss: 0.9495(Real: 0.3377 + Fake: 0.6118)... Generator Loss: 1.3165
# Epoch 79/300... Discriminator Loss: 0.9801(Real: 0.5542 + Fake: 0.4260)... Generator Loss: 1.4504
# Epoch 80/300... Discriminator Loss: 0.9089(Real: 0.4347 + Fake: 0.4741)... Generator Loss: 1.3715
# Epoch 81/300... Discriminator Loss: 0.9299(Real: 0.3335 + Fake: 0.5963)... Generator Loss: 1.1902
# Epoch 82/300... Discriminator Loss: 1.2662(Real: 0.5663 + Fake: 0.7000)... Generator Loss: 1.0953
# Epoch 83/300... Discriminator Loss: 0.7831(Real: 0.3318 + Fake: 0.4513)... Generator Loss: 1.4068
# Epoch 84/300... Discriminator Loss: 1.0090(Real: 0.5432 + Fake: 0.4658)... Generator Loss: 1.6192
# Epoch 85/300... Discriminator Loss: 0.7330(Real: 0.4016 + Fake: 0.3314)... Generator Loss: 1.7263
# Epoch 86/300... Discriminator Loss: 0.7324(Real: 0.3590 + Fake: 0.3735)... Generator Loss: 1.6865
# Epoch 87/300... Discriminator Loss: 0.9393(Real: 0.4308 + Fake: 0.5085)... Generator Loss: 1.3674
# Epoch 88/300... Discriminator Loss: 0.9262(Real: 0.4586 + Fake: 0.4676)... Generator Loss: 1.4517
# Epoch 89/300... Discriminator Loss: 0.8890(Real: 0.3529 + Fake: 0.5361)... Generator Loss: 1.0959
# Epoch 90/300... Discriminator Loss: 0.7515(Real: 0.4328 + Fake: 0.3187)... Generator Loss: 1.6687
# Epoch 91/300... Discriminator Loss: 0.9588(Real: 0.6858 + Fake: 0.2729)... Generator Loss: 1.9117
# Epoch 92/300... Discriminator Loss: 0.8284(Real: 0.4577 + Fake: 0.3707)... Generator Loss: 1.5869
# Epoch 93/300... Discriminator Loss: 1.1611(Real: 0.5131 + Fake: 0.6480)... Generator Loss: 1.2473
# Epoch 94/300... Discriminator Loss: 1.0099(Real: 0.4345 + Fake: 0.5755)... Generator Loss: 1.3311
# Epoch 95/300... Discriminator Loss: 0.7788(Real: 0.3307 + Fake: 0.4481)... Generator Loss: 1.3956
# Epoch 96/300... Discriminator Loss: 0.9193(Real: 0.4679 + Fake: 0.4514)... Generator Loss: 1.3192
# Epoch 97/300... Discriminator Loss: 0.8816(Real: 0.4026 + Fake: 0.4790)... Generator Loss: 1.3616
# Epoch 98/300... Discriminator Loss: 0.8904(Real: 0.4429 + Fake: 0.4475)... Generator Loss: 1.5021
# Epoch 99/300... Discriminator Loss: 0.9640(Real: 0.3357 + Fake: 0.6282)... Generator Loss: 1.1779
# Epoch 100/300... Discriminator Loss: 0.7763(Real: 0.3662 + Fake: 0.4101)... Generator Loss: 1.4441
# Epoch 101/300... Discriminator Loss: 0.9159(Real: 0.4928 + Fake: 0.4231)... Generator Loss: 1.4604
# Epoch 102/300... Discriminator Loss: 1.0093(Real: 0.5600 + Fake: 0.4493)... Generator Loss: 1.5317
# Epoch 103/300... Discriminator Loss: 0.7434(Real: 0.4503 + Fake: 0.2931)... Generator Loss: 1.7055
# Epoch 104/300... Discriminator Loss: 0.8715(Real: 0.3602 + Fake: 0.5113)... Generator Loss: 1.2566
# Epoch 105/300... Discriminator Loss: 0.8877(Real: 0.4795 + Fake: 0.4082)... Generator Loss: 1.4925
# Epoch 106/300... Discriminator Loss: 0.6819(Real: 0.4479 + Fake: 0.2340)... Generator Loss: 1.9692
# Epoch 107/300... Discriminator Loss: 0.7572(Real: 0.2656 + Fake: 0.4916)... Generator Loss: 1.3138
# Epoch 108/300... Discriminator Loss: 0.7960(Real: 0.5043 + Fake: 0.2917)... Generator Loss: 1.7081
# Epoch 109/300... Discriminator Loss: 0.6701(Real: 0.3568 + Fake: 0.3132)... Generator Loss: 1.8181
# Epoch 110/300... Discriminator Loss: 0.8498(Real: 0.4870 + Fake: 0.3628)... Generator Loss: 1.6345
# Epoch 111/300... Discriminator Loss: 0.7484(Real: 0.3223 + Fake: 0.4261)... Generator Loss: 1.5915
# Epoch 112/300... Discriminator Loss: 0.9274(Real: 0.3706 + Fake: 0.5568)... Generator Loss: 1.2459
# Epoch 113/300... Discriminator Loss: 0.7858(Real: 0.4651 + Fake: 0.3207)... Generator Loss: 1.8379
# Epoch 114/300... Discriminator Loss: 0.8945(Real: 0.4300 + Fake: 0.4646)... Generator Loss: 1.4209
# Epoch 115/300... Discriminator Loss: 0.7569(Real: 0.4461 + Fake: 0.3108)... Generator Loss: 1.7963
# Epoch 116/300... Discriminator Loss: 0.6151(Real: 0.3243 + Fake: 0.2907)... Generator Loss: 1.6825
# Epoch 117/300... Discriminator Loss: 0.8620(Real: 0.5065 + Fake: 0.3554)... Generator Loss: 1.6193
# Epoch 118/300... Discriminator Loss: 0.9685(Real: 0.2702 + Fake: 0.6983)... Generator Loss: 1.0722
# Epoch 119/300... Discriminator Loss: 0.8390(Real: 0.5136 + Fake: 0.3254)... Generator Loss: 1.8520
# Epoch 120/300... Discriminator Loss: 0.8738(Real: 0.4173 + Fake: 0.4565)... Generator Loss: 1.4798
# Epoch 121/300... Discriminator Loss: 0.7511(Real: 0.3401 + Fake: 0.4110)... Generator Loss: 1.4603
# Epoch 122/300... Discriminator Loss: 0.8810(Real: 0.3586 + Fake: 0.5224)... Generator Loss: 1.3825
# Epoch 123/300... Discriminator Loss: 0.9504(Real: 0.3951 + Fake: 0.5553)... Generator Loss: 1.3979
# Epoch 124/300... Discriminator Loss: 0.8767(Real: 0.4797 + Fake: 0.3969)... Generator Loss: 1.5519
# Epoch 125/300... Discriminator Loss: 1.0247(Real: 0.5418 + Fake: 0.4829)... Generator Loss: 1.4296
# Epoch 126/300... Discriminator Loss: 0.7577(Real: 0.3990 + Fake: 0.3587)... Generator Loss: 1.5129
# Epoch 127/300... Discriminator Loss: 1.0459(Real: 0.5896 + Fake: 0.4563)... Generator Loss: 1.4283
# Epoch 128/300... Discriminator Loss: 0.6667(Real: 0.4086 + Fake: 0.2582)... Generator Loss: 2.1701
# Epoch 129/300... Discriminator Loss: 0.8579(Real: 0.3966 + Fake: 0.4613)... Generator Loss: 1.4697
# Epoch 130/300... Discriminator Loss: 0.6577(Real: 0.4069 + Fake: 0.2507)... Generator Loss: 1.9504
# Epoch 131/300... Discriminator Loss: 1.0054(Real: 0.5981 + Fake: 0.4072)... Generator Loss: 1.4917
# Epoch 132/300... Discriminator Loss: 0.8109(Real: 0.4355 + Fake: 0.3753)... Generator Loss: 1.5952
# Epoch 133/300... Discriminator Loss: 0.9227(Real: 0.4868 + Fake: 0.4360)... Generator Loss: 1.4918
# Epoch 134/300... Discriminator Loss: 0.7544(Real: 0.4602 + Fake: 0.2942)... Generator Loss: 1.8334
# Epoch 135/300... Discriminator Loss: 1.0177(Real: 0.6031 + Fake: 0.4146)... Generator Loss: 1.4933
# Epoch 136/300... Discriminator Loss: 0.7769(Real: 0.4076 + Fake: 0.3693)... Generator Loss: 1.6396
# Epoch 137/300... Discriminator Loss: 0.8400(Real: 0.4951 + Fake: 0.3449)... Generator Loss: 1.7572
# Epoch 138/300... Discriminator Loss: 0.9882(Real: 0.5993 + Fake: 0.3889)... Generator Loss: 1.4617
# Epoch 139/300... Discriminator Loss: 0.8815(Real: 0.4153 + Fake: 0.4662)... Generator Loss: 1.3820
# Epoch 140/300... Discriminator Loss: 0.9168(Real: 0.3748 + Fake: 0.5420)... Generator Loss: 1.2551
# Epoch 141/300... Discriminator Loss: 0.7375(Real: 0.3475 + Fake: 0.3900)... Generator Loss: 1.5766
# Epoch 142/300... Discriminator Loss: 1.1254(Real: 0.6072 + Fake: 0.5182)... Generator Loss: 1.4079
# Epoch 143/300... Discriminator Loss: 0.9018(Real: 0.3538 + Fake: 0.5480)... Generator Loss: 1.2215
# Epoch 144/300... Discriminator Loss: 0.9031(Real: 0.4704 + Fake: 0.4327)... Generator Loss: 1.3784
# Epoch 145/300... Discriminator Loss: 0.7915(Real: 0.4280 + Fake: 0.3635)... Generator Loss: 1.7894
# Epoch 146/300... Discriminator Loss: 0.7273(Real: 0.3946 + Fake: 0.3326)... Generator Loss: 1.4725
# Epoch 147/300... Discriminator Loss: 0.7709(Real: 0.3935 + Fake: 0.3774)... Generator Loss: 1.7472
# Epoch 148/300... Discriminator Loss: 1.0585(Real: 0.7567 + Fake: 0.3018)... Generator Loss: 1.7750
# Epoch 149/300... Discriminator Loss: 0.9537(Real: 0.5957 + Fake: 0.3580)... Generator Loss: 1.6003
# Epoch 150/300... Discriminator Loss: 0.8933(Real: 0.3747 + Fake: 0.5186)... Generator Loss: 1.2399
# Epoch 151/300... Discriminator Loss: 0.8943(Real: 0.5310 + Fake: 0.3633)... Generator Loss: 1.5262
# Epoch 152/300... Discriminator Loss: 0.9957(Real: 0.6748 + Fake: 0.3208)... Generator Loss: 1.7782
# Epoch 153/300... Discriminator Loss: 0.7813(Real: 0.4883 + Fake: 0.2929)... Generator Loss: 1.7281
# Epoch 154/300... Discriminator Loss: 0.9624(Real: 0.3321 + Fake: 0.6303)... Generator Loss: 1.2777
# Epoch 155/300... Discriminator Loss: 0.8979(Real: 0.5921 + Fake: 0.3058)... Generator Loss: 1.8832
# Epoch 156/300... Discriminator Loss: 0.8726(Real: 0.4863 + Fake: 0.3863)... Generator Loss: 1.4920
# Epoch 157/300... Discriminator Loss: 1.0164(Real: 0.4868 + Fake: 0.5296)... Generator Loss: 1.5136
# Epoch 158/300... Discriminator Loss: 0.9287(Real: 0.5088 + Fake: 0.4199)... Generator Loss: 1.5275
# Epoch 159/300... Discriminator Loss: 0.7587(Real: 0.3768 + Fake: 0.3819)... Generator Loss: 1.5919
# Epoch 160/300... Discriminator Loss: 0.8708(Real: 0.5594 + Fake: 0.3114)... Generator Loss: 1.8402
# Epoch 161/300... Discriminator Loss: 1.0139(Real: 0.6093 + Fake: 0.4046)... Generator Loss: 1.6889
# Epoch 162/300... Discriminator Loss: 0.6915(Real: 0.3789 + Fake: 0.3126)... Generator Loss: 1.7604
# Epoch 163/300... Discriminator Loss: 0.7500(Real: 0.3379 + Fake: 0.4120)... Generator Loss: 1.5729
# Epoch 164/300... Discriminator Loss: 0.8876(Real: 0.4812 + Fake: 0.4063)... Generator Loss: 1.4725
# Epoch 165/300... Discriminator Loss: 0.7389(Real: 0.4057 + Fake: 0.3332)... Generator Loss: 1.7711
# Epoch 166/300... Discriminator Loss: 0.9139(Real: 0.5779 + Fake: 0.3360)... Generator Loss: 1.7068
# Epoch 167/300... Discriminator Loss: 0.8560(Real: 0.4117 + Fake: 0.4443)... Generator Loss: 1.4992
# Epoch 168/300... Discriminator Loss: 0.7522(Real: 0.3068 + Fake: 0.4454)... Generator Loss: 1.4306
# Epoch 169/300... Discriminator Loss: 0.9674(Real: 0.4442 + Fake: 0.5231)... Generator Loss: 1.2713
# Epoch 170/300... Discriminator Loss: 0.9592(Real: 0.4244 + Fake: 0.5348)... Generator Loss: 1.5278
# Epoch 171/300... Discriminator Loss: 0.8766(Real: 0.4314 + Fake: 0.4451)... Generator Loss: 1.4925
# Epoch 172/300... Discriminator Loss: 1.0399(Real: 0.4541 + Fake: 0.5858)... Generator Loss: 1.1732
# Epoch 173/300... Discriminator Loss: 0.8069(Real: 0.4538 + Fake: 0.3532)... Generator Loss: 1.7433
# Epoch 174/300... Discriminator Loss: 0.9280(Real: 0.4440 + Fake: 0.4840)... Generator Loss: 1.1596
# Epoch 175/300... Discriminator Loss: 0.8216(Real: 0.3454 + Fake: 0.4762)... Generator Loss: 1.3325
# Epoch 176/300... Discriminator Loss: 0.8323(Real: 0.4112 + Fake: 0.4210)... Generator Loss: 1.4069
# Epoch 177/300... Discriminator Loss: 0.7972(Real: 0.3348 + Fake: 0.4624)... Generator Loss: 1.4197
# Epoch 178/300... Discriminator Loss: 0.8497(Real: 0.4956 + Fake: 0.3541)... Generator Loss: 1.6934
# Epoch 179/300... Discriminator Loss: 0.8167(Real: 0.3916 + Fake: 0.4250)... Generator Loss: 1.3543
# Epoch 180/300... Discriminator Loss: 0.7605(Real: 0.3603 + Fake: 0.4002)... Generator Loss: 1.5499
# Epoch 181/300... Discriminator Loss: 0.8447(Real: 0.4335 + Fake: 0.4112)... Generator Loss: 1.5380
# Epoch 182/300... Discriminator Loss: 0.8050(Real: 0.3986 + Fake: 0.4064)... Generator Loss: 1.3239
# Epoch 183/300... Discriminator Loss: 0.8585(Real: 0.5264 + Fake: 0.3320)... Generator Loss: 1.8783
# Epoch 184/300... Discriminator Loss: 0.9533(Real: 0.3880 + Fake: 0.5652)... Generator Loss: 1.1495
# Epoch 185/300... Discriminator Loss: 0.7844(Real: 0.3972 + Fake: 0.3871)... Generator Loss: 1.6522
# Epoch 186/300... Discriminator Loss: 0.8055(Real: 0.3778 + Fake: 0.4276)... Generator Loss: 1.3808
# Epoch 187/300... Discriminator Loss: 0.7836(Real: 0.3666 + Fake: 0.4170)... Generator Loss: 1.5025
# Epoch 188/300... Discriminator Loss: 1.0347(Real: 0.4734 + Fake: 0.5613)... Generator Loss: 1.2947
# Epoch 189/300... Discriminator Loss: 0.9071(Real: 0.4187 + Fake: 0.4884)... Generator Loss: 1.2148
# Epoch 190/300... Discriminator Loss: 0.8065(Real: 0.4087 + Fake: 0.3978)... Generator Loss: 1.5121
# Epoch 191/300... Discriminator Loss: 0.9673(Real: 0.3636 + Fake: 0.6037)... Generator Loss: 1.2935
# Epoch 192/300... Discriminator Loss: 0.9084(Real: 0.3705 + Fake: 0.5379)... Generator Loss: 1.1686
# Epoch 193/300... Discriminator Loss: 1.0614(Real: 0.6347 + Fake: 0.4267)... Generator Loss: 1.4928
# Epoch 194/300... Discriminator Loss: 0.9297(Real: 0.5249 + Fake: 0.4048)... Generator Loss: 1.5516
# Epoch 195/300... Discriminator Loss: 1.0344(Real: 0.6523 + Fake: 0.3821)... Generator Loss: 1.6593
# Epoch 196/300... Discriminator Loss: 0.6788(Real: 0.3033 + Fake: 0.3755)... Generator Loss: 1.5228
# Epoch 197/300... Discriminator Loss: 0.8745(Real: 0.3354 + Fake: 0.5391)... Generator Loss: 1.3607
# Epoch 198/300... Discriminator Loss: 0.8468(Real: 0.4796 + Fake: 0.3672)... Generator Loss: 1.5598
# Epoch 199/300... Discriminator Loss: 0.9471(Real: 0.5527 + Fake: 0.3944)... Generator Loss: 1.5866
# Epoch 200/300... Discriminator Loss: 1.0307(Real: 0.3649 + Fake: 0.6658)... Generator Loss: 1.1550
# Epoch 201/300... Discriminator Loss: 0.9807(Real: 0.6061 + Fake: 0.3746)... Generator Loss: 1.6015
# Epoch 202/300... Discriminator Loss: 0.8462(Real: 0.4355 + Fake: 0.4107)... Generator Loss: 1.5579
# Epoch 203/300... Discriminator Loss: 0.8271(Real: 0.4696 + Fake: 0.3575)... Generator Loss: 1.5886
# Epoch 204/300... Discriminator Loss: 1.0670(Real: 0.5098 + Fake: 0.5572)... Generator Loss: 1.1858
# Epoch 205/300... Discriminator Loss: 0.8560(Real: 0.4615 + Fake: 0.3945)... Generator Loss: 1.5171
# Epoch 206/300... Discriminator Loss: 0.8066(Real: 0.4833 + Fake: 0.3233)... Generator Loss: 1.8090
# Epoch 207/300... Discriminator Loss: 0.8849(Real: 0.4414 + Fake: 0.4435)... Generator Loss: 1.4501
# Epoch 208/300... Discriminator Loss: 0.7737(Real: 0.4254 + Fake: 0.3482)... Generator Loss: 1.7774
# Epoch 209/300... Discriminator Loss: 0.9575(Real: 0.5849 + Fake: 0.3726)... Generator Loss: 1.6147
# Epoch 210/300... Discriminator Loss: 1.0738(Real: 0.4314 + Fake: 0.6424)... Generator Loss: 1.1190
# Epoch 211/300... Discriminator Loss: 0.7510(Real: 0.4732 + Fake: 0.2778)... Generator Loss: 1.9250
# Epoch 212/300... Discriminator Loss: 0.7563(Real: 0.4269 + Fake: 0.3294)... Generator Loss: 1.7233
# Epoch 213/300... Discriminator Loss: 1.2197(Real: 0.7110 + Fake: 0.5088)... Generator Loss: 1.3531
# Epoch 214/300... Discriminator Loss: 0.8670(Real: 0.4886 + Fake: 0.3784)... Generator Loss: 1.5640
# Epoch 215/300... Discriminator Loss: 0.9094(Real: 0.4884 + Fake: 0.4211)... Generator Loss: 1.6043
# Epoch 216/300... Discriminator Loss: 0.8324(Real: 0.5574 + Fake: 0.2750)... Generator Loss: 1.9120
# Epoch 217/300... Discriminator Loss: 0.7214(Real: 0.3005 + Fake: 0.4209)... Generator Loss: 1.4771
# Epoch 218/300... Discriminator Loss: 0.8786(Real: 0.4252 + Fake: 0.4534)... Generator Loss: 1.2307
# Epoch 219/300... Discriminator Loss: 0.9261(Real: 0.3912 + Fake: 0.5349)... Generator Loss: 1.3229
# Epoch 220/300... Discriminator Loss: 0.8477(Real: 0.4093 + Fake: 0.4384)... Generator Loss: 1.4166
# Epoch 221/300... Discriminator Loss: 0.9621(Real: 0.5552 + Fake: 0.4069)... Generator Loss: 1.7565
# Epoch 222/300... Discriminator Loss: 0.9786(Real: 0.5812 + Fake: 0.3974)... Generator Loss: 1.4549
# Epoch 223/300... Discriminator Loss: 0.8533(Real: 0.3721 + Fake: 0.4812)... Generator Loss: 1.3958
# Epoch 224/300... Discriminator Loss: 1.1549(Real: 0.6311 + Fake: 0.5238)... Generator Loss: 1.3232
# Epoch 225/300... Discriminator Loss: 0.8142(Real: 0.5064 + Fake: 0.3078)... Generator Loss: 1.8779
# Epoch 226/300... Discriminator Loss: 0.8941(Real: 0.4026 + Fake: 0.4915)... Generator Loss: 1.6276
# Epoch 227/300... Discriminator Loss: 0.8452(Real: 0.5800 + Fake: 0.2652)... Generator Loss: 1.9601
# Epoch 228/300... Discriminator Loss: 0.9432(Real: 0.4394 + Fake: 0.5037)... Generator Loss: 1.4339
# Epoch 229/300... Discriminator Loss: 0.8963(Real: 0.5334 + Fake: 0.3630)... Generator Loss: 1.7176
# Epoch 230/300... Discriminator Loss: 0.7302(Real: 0.2980 + Fake: 0.4322)... Generator Loss: 1.4412
# Epoch 231/300... Discriminator Loss: 0.8341(Real: 0.4455 + Fake: 0.3885)... Generator Loss: 1.4585
# Epoch 232/300... Discriminator Loss: 0.8731(Real: 0.4370 + Fake: 0.4361)... Generator Loss: 1.7309
# Epoch 233/300... Discriminator Loss: 0.9053(Real: 0.4884 + Fake: 0.4169)... Generator Loss: 1.6850
# Epoch 234/300... Discriminator Loss: 0.7399(Real: 0.3002 + Fake: 0.4397)... Generator Loss: 1.5429
# Epoch 235/300... Discriminator Loss: 0.9045(Real: 0.4560 + Fake: 0.4485)... Generator Loss: 1.6516
# Epoch 236/300... Discriminator Loss: 0.8867(Real: 0.4236 + Fake: 0.4632)... Generator Loss: 1.5776
# Epoch 237/300... Discriminator Loss: 0.9684(Real: 0.4931 + Fake: 0.4753)... Generator Loss: 1.6342
# Epoch 238/300... Discriminator Loss: 0.8162(Real: 0.5041 + Fake: 0.3121)... Generator Loss: 1.7175
# Epoch 239/300... Discriminator Loss: 0.8642(Real: 0.5653 + Fake: 0.2989)... Generator Loss: 1.6794
# Epoch 240/300... Discriminator Loss: 0.8485(Real: 0.4244 + Fake: 0.4240)... Generator Loss: 1.6115
# Epoch 241/300... Discriminator Loss: 1.0079(Real: 0.5257 + Fake: 0.4822)... Generator Loss: 1.4976
# Epoch 242/300... Discriminator Loss: 0.9200(Real: 0.5181 + Fake: 0.4019)... Generator Loss: 1.7334
# Epoch 243/300... Discriminator Loss: 0.8466(Real: 0.4311 + Fake: 0.4154)... Generator Loss: 1.5762
# Epoch 244/300... Discriminator Loss: 0.9402(Real: 0.4887 + Fake: 0.4516)... Generator Loss: 1.4127
# Epoch 245/300... Discriminator Loss: 0.7526(Real: 0.3544 + Fake: 0.3982)... Generator Loss: 1.5968
# Epoch 246/300... Discriminator Loss: 0.8988(Real: 0.4118 + Fake: 0.4869)... Generator Loss: 1.2289
# Epoch 247/300... Discriminator Loss: 0.7883(Real: 0.4670 + Fake: 0.3213)... Generator Loss: 1.9333
# Epoch 248/300... Discriminator Loss: 0.8841(Real: 0.4936 + Fake: 0.3906)... Generator Loss: 1.6451
# Epoch 249/300... Discriminator Loss: 0.8141(Real: 0.3229 + Fake: 0.4912)... Generator Loss: 1.4045
# Epoch 250/300... Discriminator Loss: 0.8101(Real: 0.3157 + Fake: 0.4944)... Generator Loss: 1.4863
# Epoch 251/300... Discriminator Loss: 0.8987(Real: 0.4604 + Fake: 0.4382)... Generator Loss: 1.5649
# Epoch 252/300... Discriminator Loss: 0.9219(Real: 0.3512 + Fake: 0.5706)... Generator Loss: 1.3696
# Epoch 253/300... Discriminator Loss: 0.9456(Real: 0.4547 + Fake: 0.4909)... Generator Loss: 1.4302
# Epoch 254/300... Discriminator Loss: 0.9718(Real: 0.4248 + Fake: 0.5470)... Generator Loss: 1.3895
# Epoch 255/300... Discriminator Loss: 0.8331(Real: 0.4544 + Fake: 0.3787)... Generator Loss: 1.6112
# Epoch 256/300... Discriminator Loss: 0.9568(Real: 0.4367 + Fake: 0.5200)... Generator Loss: 1.3910
# Epoch 257/300... Discriminator Loss: 0.8241(Real: 0.4277 + Fake: 0.3964)... Generator Loss: 1.5167
# Epoch 258/300... Discriminator Loss: 0.7433(Real: 0.4440 + Fake: 0.2993)... Generator Loss: 1.8610
# Epoch 259/300... Discriminator Loss: 1.0150(Real: 0.7060 + Fake: 0.3091)... Generator Loss: 2.0380
# Epoch 260/300... Discriminator Loss: 0.7892(Real: 0.4101 + Fake: 0.3791)... Generator Loss: 1.5701
# Epoch 261/300... Discriminator Loss: 1.0279(Real: 0.4553 + Fake: 0.5727)... Generator Loss: 1.4822
# Epoch 262/300... Discriminator Loss: 0.9502(Real: 0.3831 + Fake: 0.5672)... Generator Loss: 1.4554
# Epoch 263/300... Discriminator Loss: 0.9165(Real: 0.4730 + Fake: 0.4436)... Generator Loss: 1.5539
# Epoch 264/300... Discriminator Loss: 0.6704(Real: 0.3884 + Fake: 0.2820)... Generator Loss: 1.7739
# Epoch 265/300... Discriminator Loss: 1.0162(Real: 0.3734 + Fake: 0.6428)... Generator Loss: 1.1918
# Epoch 266/300... Discriminator Loss: 0.9772(Real: 0.5063 + Fake: 0.4709)... Generator Loss: 1.6030
# Epoch 267/300... Discriminator Loss: 0.8587(Real: 0.3053 + Fake: 0.5534)... Generator Loss: 1.1957
# Epoch 268/300... Discriminator Loss: 0.8269(Real: 0.3426 + Fake: 0.4844)... Generator Loss: 1.4134
# Epoch 269/300... Discriminator Loss: 0.6750(Real: 0.4076 + Fake: 0.2674)... Generator Loss: 2.1145
# Epoch 270/300... Discriminator Loss: 1.0773(Real: 0.5837 + Fake: 0.4936)... Generator Loss: 1.4354
# Epoch 271/300... Discriminator Loss: 0.8636(Real: 0.6152 + Fake: 0.2484)... Generator Loss: 2.0160
# Epoch 272/300... Discriminator Loss: 0.6671(Real: 0.3119 + Fake: 0.3551)... Generator Loss: 1.6902
# Epoch 273/300... Discriminator Loss: 0.8516(Real: 0.5340 + Fake: 0.3176)... Generator Loss: 1.8268
# Epoch 274/300... Discriminator Loss: 0.8908(Real: 0.5143 + Fake: 0.3765)... Generator Loss: 1.5633
# Epoch 275/300... Discriminator Loss: 0.8950(Real: 0.3768 + Fake: 0.5182)... Generator Loss: 1.4603
# Epoch 276/300... Discriminator Loss: 0.8128(Real: 0.4580 + Fake: 0.3548)... Generator Loss: 1.8137
# Epoch 277/300... Discriminator Loss: 0.9117(Real: 0.5379 + Fake: 0.3739)... Generator Loss: 1.6395
# Epoch 278/300... Discriminator Loss: 0.8886(Real: 0.5512 + Fake: 0.3374)... Generator Loss: 1.7997
# Epoch 279/300... Discriminator Loss: 1.0399(Real: 0.6493 + Fake: 0.3906)... Generator Loss: 1.5532
# Epoch 280/300... Discriminator Loss: 0.7753(Real: 0.4471 + Fake: 0.3282)... Generator Loss: 1.7827
# Epoch 281/300... Discriminator Loss: 1.1347(Real: 0.8599 + Fake: 0.2749)... Generator Loss: 2.1422
# Epoch 282/300... Discriminator Loss: 0.9363(Real: 0.6033 + Fake: 0.3331)... Generator Loss: 1.8406
# Epoch 283/300... Discriminator Loss: 0.9942(Real: 0.4824 + Fake: 0.5118)... Generator Loss: 1.4367
# Epoch 284/300... Discriminator Loss: 0.9998(Real: 0.3082 + Fake: 0.6916)... Generator Loss: 1.2165
# Epoch 285/300... Discriminator Loss: 0.6821(Real: 0.2553 + Fake: 0.4268)... Generator Loss: 1.6546
# Epoch 286/300... Discriminator Loss: 0.8269(Real: 0.5014 + Fake: 0.3255)... Generator Loss: 1.9184
# Epoch 287/300... Discriminator Loss: 0.8883(Real: 0.6331 + Fake: 0.2552)... Generator Loss: 2.0579
# Epoch 288/300... Discriminator Loss: 0.8918(Real: 0.3458 + Fake: 0.5460)... Generator Loss: 1.3721
# Epoch 289/300... Discriminator Loss: 0.6084(Real: 0.2796 + Fake: 0.3287)... Generator Loss: 1.6185
# Epoch 290/300... Discriminator Loss: 0.9830(Real: 0.5870 + Fake: 0.3960)... Generator Loss: 1.8459
# Epoch 291/300... Discriminator Loss: 0.5931(Real: 0.3664 + Fake: 0.2267)... Generator Loss: 1.9356
# Epoch 292/300... Discriminator Loss: 0.8972(Real: 0.3135 + Fake: 0.5837)... Generator Loss: 1.2994
# Epoch 293/300... Discriminator Loss: 0.7250(Real: 0.3019 + Fake: 0.4230)... Generator Loss: 1.5370
# Epoch 294/300... Discriminator Loss: 0.8325(Real: 0.4108 + Fake: 0.4218)... Generator Loss: 1.4729
# Epoch 295/300... Discriminator Loss: 0.7151(Real: 0.3555 + Fake: 0.3596)... Generator Loss: 1.7141
# Epoch 296/300... Discriminator Loss: 0.7667(Real: 0.2808 + Fake: 0.4858)... Generator Loss: 1.2915
# Epoch 297/300... Discriminator Loss: 0.8024(Real: 0.4956 + Fake: 0.3069)... Generator Loss: 1.7486
# Epoch 298/300... Discriminator Loss: 0.7438(Real: 0.3117 + Fake: 0.4321)... Generator Loss: 1.4360
# Epoch 299/300... Discriminator Loss: 0.7955(Real: 0.4372 + Fake: 0.3584)... Generator Loss: 1.7749
# Epoch 300/300... Discriminator Loss: 0.7000(Real: 0.4286 + Fake: 0.2715)... Generator Loss: 1.8747

# %%
fig, ax = plt.subplots(figsize=(20,7))
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator Total Loss')
plt.plot(losses.T[1], label='Discriminator Real Loss')
plt.plot(losses.T[2], label='Discriminator Fake Loss')
plt.plot(losses.T[3], label='Generator')
plt.title("Training Losses")
plt.legend()

# %%
# Load samples from generator taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pickle.load(f)

# %%
def view_samples(epoch, samples):
    """
    epoch代表第几次迭代的图像
    samples为我们的采样结果
    """
    fig, axes = plt.subplots(figsize=(7,7), nrows=5, ncols=5, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch][1]): # 这里samples[epoch][1]代表生成的图像结果，而[0]代表对应的logits
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((28,28)), cmap='Greys_r')
    
    return fig, axes

# %%
# 加载生成器变量
saver = tf.train.Saver(var_list=g_vars)
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    sample_noise = np.random.uniform(-1, 1, size=(25, noise_size))
    gen_samples = sess.run(get_generator(noise_img, g_units, img_size, reuse=True),
                           feed_dict={noise_img: sample_noise})
# Out:
# WARNING:tensorflow:From C:\ProgramData\Anaconda3\lib\site-packages\tensorflow\python\training\saver.py:1266: checkpoint_exists (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use standard file APIs to check for files with this prefix.
# INFO:tensorflow:Restoring parameters from checkpoints\generator.ckpt

# %%
_ = view_samples(-1, samples) # 显示最后一轮的outputs

# %%
# 指定要查看的轮次
epoch_idx = [0, 5, 10, 20, 40, 60, 80, 100, 150, 250] # 一共300轮
show_imgs = []
for i in epoch_idx:
    show_imgs.append(samples[i][1])

# %%
# 指定图片形状
rows, cols = 10, 25
fig, axes = plt.subplots(figsize=(30,12), nrows=rows, ncols=cols, sharex=True, sharey=True)

idx = range(0, epochs, int(epochs/rows))

for sample, ax_row in zip(show_imgs, axes):
    for img, ax in zip(sample[::int(len(sample)/cols)], ax_row):
        ax.imshow(img.reshape((28,28)), cmap='Greys_r')
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)

# %%
# 加载我们的生成器变量
saver = tf.train.Saver(var_list=g_vars)
with tf.Session() as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    sample_noise = np.random.uniform(-1, 1, size=(25, noise_size))
    gen_samples = sess.run(get_generator(noise_img, g_units, img_size, reuse=True),
                           feed_dict={noise_img: sample_noise})
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints\generator.ckpt

# %%
_ = view_samples(0, [gen_samples])
